# %%
pip install selenium
# Out:
# Collecting selenium
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/fc/df/a8972c41279fc9e9404cad87bc1f4d6d3d824b84c5c072dca0e986a89680/selenium-4.14.0-py3-none-any.whl.metadata
#   Downloading selenium-4.14.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting urllib3[socks]<3,>=1.26 (from selenium)
#   Obtaining dependency information for urllib3[socks]<3,>=1.26 from https://files.pythonhosted.org/packages/26/40/9957270221b6d3e9a3b92fdfba80dd5c9661ff45a664b47edd5d00f707f5/urllib3-2.0.6-py3-none-any.whl.metadata
#   Downloading urllib3-2.0.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting trio~=0.17 (from selenium)
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/a3/dd/b61fa61b186d3267ef3903048fbee29132963ae762fb70b08d4a3cd6f7aa/trio-0.22.2-py3-none-any.whl.metadata
#   Downloading trio-0.22.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\mind-graph\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\mind-graph\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\mind-graph\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\mind-graph\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (2.8)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in c:\users\mind-graph\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\mind-graph\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Collecting exceptiongroup>=1.0.0rc9 (from trio~=0.17->selenium)
#   Obtaining dependency information for exceptiongroup>=1.0.0rc9 from https://files.pythonhosted.org/packages/ad/83/b71e58666f156a39fb29417e4c8ca4bc7400c0dd4ed9e8842ab54dc8c344/exceptiongroup-1.1.3-py3-none-any.whl.metadata
#   Downloading exceptiongroup-1.1.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\mind-graph\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\mind-graph\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB 1.5 MB/s eta 0:00:00
# Downloading selenium-4.14.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 9.9/9.9 MB 18.6 MB/s eta 0:00:00
# Downloading trio-0.22.2-py3-none-any.whl (400 kB)
#    --------------------------------------- 400.2/400.2 kB 26.0 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Downloading urllib3-2.0.6-py3-none-any.whl (123 kB)
#    ---------------------------------------- 123.8/123.8 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: urllib3, outcome, h11, exceptiongroup, wsproto, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed exceptiongroup-1.1.3 h11-0.14.0 outcome-1.2.0 selenium-4.14.0 trio-0.22.2 trio-websocket-0.11.1 urllib3-1.26.11 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# requests 2.21.0 requires urllib3<1.25,>=1.21.1, but you have urllib3 2.0.6 which is incompatible.
# tensorboard 2.11.2 requires google-auth<3,>=1.6.3, but you have google-auth 1.4.2 which is incompatible.
# anaconda-client 1.11.0 requires six>=1.15.0, but you have six 1.12.0 which is incompatible.
# botocore 1.27.28 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.0.6 which is incompatible.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# conda-repo-cli 1.0.20 requires requests==2.28.1, but you have requests 2.21.0 which is incompatible.
# cookiecutter 1.7.3 requires requests>=2.23.0, but you have requests 2.21.0 which is incompatible.
# distributed 2022.7.0 requires tornado<6.2,>=6.0.3, but you have tornado 6.2 which is incompatible.

# %%
from selenium import webdriver

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get('https://www.nasa.gov')
headlines = driver.find_elements_by_class_name("headline")
for headline in headlines:
    print(headline.text.strip())
driver.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6876\4112349489.py in <module>
#       2 driver = webdriver.Chrome()
#       3 driver.get('https://www.nasa.gov')
# ----> 4 headlines = driver.find_elements_by_class_name("headline")
#       5 for headline in headlines:
#       6     print(headline.text.strip())
#
# AttributeError: 'WebDriver' object has no attribute 'find_elements_by_class_name'

# %% [markdown]
# # For Terminal 1

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('C:\\Users\\Mind-Graph\\Downloads\\Combined Shop Data V2.xlsx')

# %%
data.head(5)
# Out:
#   SNo AIRPORT CATEGORY SUB-CATEGORY TENANT ID CONTRACT NO  \
# 0   1    KLIA      BDC                    NaN         NaN
# 1   2    KLIA      BDC                    NaN         NaN
# 2   3    KLIA      BDC                    NaN         NaN
# 3   4    KLIA      BDC                    NaN         NaN
# 4   5    KLIA      BDC                    NaN         NaN
#
#                CONCESSIONAIRE     LOT NO LOCATION      TRADE NAME BUILDING  \
# 0            CIMB Bank Berhad  MTB-3-A23      NaN        CIMB BDC
# 1            CIMB Bank Berhad  SAT-P-A28      NaN        CIMB BDC
# 2  Bank Islam Malaysia Berhad  MTB-3-A21      NaN  Bank Islam BDC
# 3  Bank Islam Malaysia Berhad  MTB-3-L11      NaN  Bank Islam BDC
# 4             RHB Bank Berhad  MTB-3-A22      NaN         RHB BDC
#
#   AREA            OPS HRS       DATE  FLAG STATUS
# 0       09:00AM - 07:00PM 2022-01-01     1   OPEN
# 1       09:00AM - 07:00PM 2022-01-01     1   OPEN
# 2                   24Hrs 2022-01-01     1   OPEN
# 3                   24Hrs 2022-01-01     1   OPEN
# 4       08:00AM - 08:00PM 2022-01-01     1   OPEN

# %%
data.columns
# Out:
# Index(['SNo', 'AIRPORT', 'CATEGORY', 'SUB-CATEGORY', 'TENANT ID',
#        'CONTRACT NO', 'CONCESSIONAIRE', 'LOT NO', 'LOCATION', 'TRADE NAME',
#        'BUILDING', 'AREA', 'OPS HRS', 'DATE', 'FLAG', 'STATUS'],
#       dtype='object')

# %%
filtered_data = data[(data['AIRPORT'] == 'T1') & (data['DATE'] == '2023-09-30') & (data['CATEGORY'].isin(['Retail', 'F&B', 'Services']))]

# %%
filtered_data
# Out:
#         SNo AIRPORT  CATEGORY SUB-CATEGORY      TENANT ID    CONTRACT NO  \
# 185094    2      T1    Retail               IS00100014491  2500000000204
# 185095    3      T1  Services        TELCO  IS00100015803  2300000000118
# 185096    4      T1    Retail    Promotion  IS00100017824  5100000000621
# 185097    5      T1       F&B               IS00100016722  2200000000254
# 185098    6      T1  Services               IS00100015756  2300000000116
# ...     ...     ...       ...          ...            ...            ...
# 185385  293      T1       F&B       Lounge  IS00100009939  3100000000730
# 185414  322      T1  Services    Promotion  IS00100017331  2300000000137
# 185415  323      T1  Services    Promotion  IS00100017331  2300000000137
# 185416  324      T1  Services    Promotion  IS00100017331  2300000000137
# 185417  325      T1  Services               IS00100017331  2300000000137
#
#                                CONCESSIONAIRE  \
# 185094  GUARDIAN HEALTH AND BEAUTY SDN. BHD.
# 185095                MAXIS BROADBAND SDN BHD
# 185096                 MNL FORTUNE ENTERPRISE
# 185097     BERJAYA KRISPY KREME DOUGHNUTS SDN
# 185098                      TUNE TALK SDN BHD
# ...                                       ...
# 185385               MALAYSIA AIRLINES BERHAD
# 185414                   GINTELL (M) SDN BHD
# 185415                   GINTELL (M) SDN BHD
# 185416                   GINTELL (M) SDN BHD
# 185417                   GINTELL (M) SDN BHD
#
#                                        LOT NO LOCATION          TRADE NAME  \
# 185094                      LOT NO. MTB-5-L13  Level 5            Guardian
# 185095                     LOT NO. MTB -3-L09  Level 3               Maxis
# 185096                             PS-MTB-TA1  Level 5  Chocolates Beryl's
# 185097                      LOT NO. MTB-5-L21  Level 5        Krispy Kreme
# 185098                     LOT NO. MTB-3-L08,  Level 3           Tune Talk
# ...                                       ...      ...                 ...
# 185385                     MAS Golden Lounge        C1                 MAB
# 185414  MC-3-A03, MC-4-A02, MC-2-L01,MC-P-A04      All             Gintell
# 185415  MC-3-A03, MC-4-A02, MC-2-L01,MC-P-A05      All             Gintell
# 185416  MC-3-A03, MC-4-A02, MC-2-L01,MC-P-A06      All             Gintell
# 185417  MC-3-A03, MC-4-A02, MC-2-L01,MC-P-A07      All             Gintell
#
#          BUILDING              AREA             OPS HRS       DATE  FLAG  \
# 185094        MTB  PUBLIC CONCOURSE            24 Hours 2023-09-30     1
# 185095        MTB  PUBLIC CONCOURSE   06:00AM - 12:00AM 2023-09-30     1
# 185096        MTB  PUBLIC CONCOURSE  07:00AM - 11:00PM  2023-09-30     1
# 185097        MTB  PUBLIC CONCOURSE            24 Hours 2023-09-30     1
# 185098        MTB  PUBLIC CONCOURSE   06:00AM - 12:00AM 2023-09-30     1
# ...           ...               ...                 ...        ...   ...
# 185385  SATELLITE     INTERNATIONAL            24 Hours 2023-09-30     1
# 185414        MTB  PUBLIC CONCOURSE            24 Hours 2023-09-30     1
# 185415        CPI     INTERNATIONAL            24 Hours 2023-09-30     1
# 185416        CPD          DOMESTIC            24 Hours 2023-09-30     1
# 185417  SATELLITE     INTERNATIONAL            24 Hours 2023-09-30     1
#
#        STATUS
# 185094   OPEN
# 185095   OPEN
# 185096   OPEN
# 185097   OPEN
# 185098   OPEN
# ...       ...
# 185385   OPEN
# 185414   OPEN
# 185415   OPEN
# 185416   OPEN
# 185417   OPEN
#
# [184 rows x 16 columns]

# %%
filtered_data['STATUS'].count()
# Out:
# 184

# %%
df = filtered_data.drop(columns=['SNo','SUB-CATEGORY','TENANT ID','CONTRACT NO','CONCESSIONAIRE','LOT NO','LOCATION','TRADE NAME','OPS HRS','AREA','BUILDING','FLAG'])

# %%
df
# Out:
#        AIRPORT  CATEGORY       DATE STATUS
# 185094      T1    Retail 2023-09-30   OPEN
# 185095      T1  Services 2023-09-30   OPEN
# 185096      T1    Retail 2023-09-30   OPEN
# 185097      T1       F&B 2023-09-30   OPEN
# 185098      T1  Services 2023-09-30   OPEN
# ...        ...       ...        ...    ...
# 185385      T1       F&B 2023-09-30   OPEN
# 185414      T1  Services 2023-09-30   OPEN
# 185415      T1  Services 2023-09-30   OPEN
# 185416      T1  Services 2023-09-30   OPEN
# 185417      T1  Services 2023-09-30   OPEN
#
# [184 rows x 4 columns]

# %%
df['STATUS'].count()
# Out:
# 184

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     AIRPORT  CATEGORY       DATE STATUS
# 0        T1    Retail 2023-09-30   OPEN
# 1        T1  Services 2023-09-30   OPEN
# 2        T1    Retail 2023-09-30   OPEN
# 3        T1       F&B 2023-09-30   OPEN
# 4        T1  Services 2023-09-30   OPEN
# ..      ...       ...        ...    ...
# 179      T1       F&B 2023-09-30   OPEN
# 180      T1  Services 2023-09-30   OPEN
# 181      T1  Services 2023-09-30   OPEN
# 182      T1  Services 2023-09-30   OPEN
# 183      T1  Services 2023-09-30   OPEN
#
# [184 rows x 4 columns]

# %% [markdown]
# # For Terminal 2

# %%
data2=pd.read_excel('C:\\Users\\Mind-Graph\\Downloads\\Combined Shop Data V2.xlsx')

# %%
filtered_data2 = data2[(data['AIRPORT'] == 'T2') & (data['DATE'] == '2023-09-30') & (data['CATEGORY'].isin(['Retail', 'F&B', 'Services']))]

# %%
df2 = filtered_data2.drop(columns=['SNo','SUB-CATEGORY','TENANT ID','CONTRACT NO','CONCESSIONAIRE','LOT NO','LOCATION','TRADE NAME','OPS HRS','AREA','BUILDING','FLAG'])

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#     AIRPORT  CATEGORY       DATE STATUS
# 0        T2    Retail 2023-09-30   OPEN
# 1        T2       F&B 2023-09-30   OPEN
# 2        T2    Retail 2023-09-30   OPEN
# 3        T2    Retail 2023-09-30   OPEN
# 4        T2    Retail 2023-09-30   OPEN
# ..      ...       ...        ...    ...
# 129      T2  Services 2023-09-30   OPEN
# 130      T2  Services 2023-09-30   OPEN
# 131      T2  Services 2023-09-30   OPEN
# 132      T2  Services 2023-09-30   OPEN
# 133      T2  Services 2023-09-30   OPEN
#
# [134 rows x 4 columns]

# %%
concatenated_df = pd.concat([df, df2], axis=0)

# %%
concatenated_df
# Out:
#     AIRPORT  CATEGORY       DATE STATUS
# 0        T1    Retail 2023-09-30   OPEN
# 1        T1  Services 2023-09-30   OPEN
# 2        T1    Retail 2023-09-30   OPEN
# 3        T1       F&B 2023-09-30   OPEN
# 4        T1  Services 2023-09-30   OPEN
# ..      ...       ...        ...    ...
# 129      T2  Services 2023-09-30   OPEN
# 130      T2  Services 2023-09-30   OPEN
# 131      T2  Services 2023-09-30   OPEN
# 132      T2  Services 2023-09-30   OPEN
# 133      T2  Services 2023-09-30   OPEN
#
# [318 rows x 4 columns]

# %%
concatenated_df['STATUS'].count()
# Out:
# 318

# %%
KUL = concatenated_df.replace({'T1': 'KUL', 'T2': 'KUL'}).groupby(['AIRPORT', 'CATEGORY', 'STATUS','DATE']).size().reset_index(name='VALUE')

# %%
T1 = df.groupby(['AIRPORT', 'CATEGORY', 'STATUS','DATE']).size().reset_index(name='VALUE')

# %%
T1
# Out:
#   AIRPORT  CATEGORY STATUS       DATE  VALUE
# 0      T1       F&B   OPEN 2023-09-30     56
# 1      T1    Retail   OPEN 2023-09-30     62
# 2      T1  Services   OPEN 2023-09-30     66

# %%
T2 = df2.groupby(['AIRPORT', 'CATEGORY', 'STATUS','DATE']).size().reset_index(name='VALUE')

# %%
T2
# Out:
#   AIRPORT  CATEGORY STATUS       DATE  VALUE
# 0      T2       F&B   OPEN 2023-09-30     39
# 1      T2    Retail   OPEN 2023-09-30     59
# 2      T2  Services   OPEN 2023-09-30     36

# %%
KUL
# Out:
#   AIRPORT  CATEGORY STATUS       DATE  VALUE
# 0     KUL       F&B   OPEN 2023-09-30     95
# 1     KUL    Retail   OPEN 2023-09-30    121
# 2     KUL  Services   OPEN 2023-09-30    102

# %%
Final_df = pd.concat([T1, T2,KUL], axis=0)

# %%
Final_df
# Out:
#   AIRPORT  CATEGORY STATUS       DATE  VALUE
# 0      T1       F&B   OPEN 2023-09-30     56
# 1      T1    Retail   OPEN 2023-09-30     62
# 2      T1  Services   OPEN 2023-09-30     66
# 0      T2       F&B   OPEN 2023-09-30     39
# 1      T2    Retail   OPEN 2023-09-30     59
# 2      T2  Services   OPEN 2023-09-30     36
# 0     KUL       F&B   OPEN 2023-09-30     95
# 1     KUL    Retail   OPEN 2023-09-30    121
# 2     KUL  Services   OPEN 2023-09-30    102

# %%
cols = ['DATE', 'AIRPORT', 'CATEGORY', 'STATUS','VALUE']
