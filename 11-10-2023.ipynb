# %%
import pandas as pd

# %%
data1=pd.read_csv('C:\\Users\\Mind-Graph\\Downloads\\nba.csv')

# %%
data1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data1.drop(columns={'Team'},inplace=True)

# %%
data1
# Out:
#               Name  Number Position   Age Height  Weight            College  \
# 0    Avery Bradley     0.0       PG  25.0    6-2   180.0              Texas
# 1      Jae Crowder    99.0       SF  25.0    6-6   235.0          Marquette
# 2     John Holland    30.0       SG  27.0    6-5   205.0  Boston University
# 3      R.J. Hunter    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Jonas Jerebko     8.0       PF  29.0   6-10   231.0                NaN
# ..             ...     ...      ...   ...    ...     ...                ...
# 453   Shelvin Mack     8.0       PG  26.0    6-3   203.0             Butler
# 454      Raul Neto    25.0       PG  24.0    6-1   179.0                NaN
# 455   Tibor Pleiss    21.0        C  26.0    7-3   256.0                NaN
# 456    Jeff Withey    24.0        C  26.0    7-0   231.0             Kansas
# 457            NaN     NaN      NaN   NaN    NaN     NaN                NaN
#
#         Salary
# 0    7730337.0
# 1    6796117.0
# ...

# %%
data=pd.read_csv('C:\\Users\\Mind-Graph\\Downloads\\nba.csv')

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data3=data['Team']

# %%
data3
# Out:
# 0      Boston Celtics
# 1      Boston Celtics
# 2      Boston Celtics
# 3      Boston Celtics
# 4      Boston Celtics
#             ...
# 453         Utah Jazz
# 454         Utah Jazz
# 455         Utah Jazz
# 456         Utah Jazz
# 457               NaN
# Name: Team, Length: 458, dtype: object

# %%
import pandas as pd

# %%
data2=pd.DataFrame(data3)

# %%
data2
# Out:
#                Team
# 0    Boston Celtics
# 1    Boston Celtics
# 2    Boston Celtics
# 3    Boston Celtics
# 4    Boston Celtics
# ..              ...
# 453       Utah Jazz
# 454       Utah Jazz
# 455       Utah Jazz
# 456       Utah Jazz
# 457             NaN
#
# [458 rows x 1 columns]
