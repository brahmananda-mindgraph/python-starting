# %%
import pandas as pd

# %%
data=pd.read_excel('C:\\Users\\Mind-Graph\\Downloads\\People Details.xlsx')

# %%
data.head()
# Out:
#               Name   age   company name   salary       type           Field
# 0     Abhisek Sahu  23.0       Accentue  10000.0  Full time    Data Science
# 1        Yash sahu  24.0         Byteiq  12000.0     Intern  Cyber security
# 2   Biswajit Nayak  21.0        Laravel  32000.0     Intern    Data Science
# 3  Satyajit Dehury  22.0            TCS  26000.0  Full time           AI/ML
# 4   Anil Kumar kar  19.0  Tech Mahindra  65000.0  Full time           AI/ML

# %%
data['company name'].fillna(130, inplace = True)

# %%
data
# Out:
#                   Name    age         company name   salary       type  \
# 0         Abhisek Sahu   23.0             Accentue  10000.0  Full time
# 1            Yash sahu   24.0               Byteiq  12000.0     Intern
# 2       Biswajit Nayak   21.0              Laravel  32000.0     Intern
# 3      Satyajit Dehury   22.0                  TCS  26000.0  Full time
# 4       Anil Kumar kar   19.0        Tech Mahindra  65000.0  Full time
# 5     Alok kumar panda   30.0            Mindgraph  20000.0     Intern
# 6         Babita sahoo   25.0                Wipro  30000.0  Full time
# 7   Nihar ranjan sahoo   31.0  Surya international   5000.0     Intern
# 8    abhishek satpathy  130.0                  abc    130.0     Intern
# 9        Diptesh Bhata   26.0                  130  56000.0  Full time
# 10   Satyanarayan rath  130.0                  130    130.0        130
#
#              Field
# 0     Data Science
# 1   Cyber security
# 2     Data Science
# 3            AI/ML
# ...

# %%
data['age'].mean()
# Out:
# 43.72727272727273

# %%
data['age'].max()
# Out:
# 130.0

# %%
data.fillna(130, inplace = True)

# %%
data
# Out:
#                   Name    age         company name   salary       type  \
# 0         Abhisek Sahu   23.0             Accentue  10000.0  Full time
# 1            Yash sahu   24.0               Byteiq  12000.0     Intern
# 2       Biswajit Nayak   21.0              Laravel  32000.0     Intern
# 3      Satyajit Dehury   22.0                  TCS  26000.0  Full time
# 4       Anil Kumar kar   19.0        Tech Mahindra  65000.0  Full time
# 5     Alok kumar panda   30.0            Mindgraph  20000.0     Intern
# 6         Babita sahoo   25.0                Wipro  30000.0  Full time
# 7   Nihar ranjan sahoo   31.0  Surya international   5000.0     Intern
# 8    abhishek satpathy  130.0                  abc    130.0     Intern
# 9        Diptesh Bhata   26.0                  130  56000.0  Full time
# 10   Satyanarayan rath  130.0                  130    130.0        130
#
#              Field
# 0     Data Science
# 1   Cyber security
# 2     Data Science
# 3            AI/ML
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          11 non-null     object
#  1   age           9 non-null      float64
#  2   company name  9 non-null      object
#  3   salary        9 non-null      float64
#  4   type          10 non-null     object
#  5   Field         8 non-null      object
# dtypes: float64(2), object(4)
# memory usage: 656.0+ bytes

# %%
new_df = data.dropna()

# %%
new_df
# Out:
#                  Name   age         company name   salary       type  \
# 0        Abhisek Sahu  23.0             Accentue  10000.0  Full time
# 1           Yash sahu  24.0               Byteiq  12000.0     Intern
# 2      Biswajit Nayak  21.0              Laravel  32000.0     Intern
# 3     Satyajit Dehury  22.0                  TCS  26000.0  Full time
# 4      Anil Kumar kar  19.0        Tech Mahindra  65000.0  Full time
# 5    Alok kumar panda  30.0            Mindgraph  20000.0     Intern
# 6        Babita sahoo  25.0                Wipro  30000.0  Full time
# 7  Nihar ranjan sahoo  31.0  Surya international   5000.0     Intern
#
#             Field
# 0    Data Science
# 1  Cyber security
# 2    Data Science
# 3           AI/ML
# 4           AI/ML
# 5    Data Science
# 6  Cyber security
# 7           AI/ML

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          8 non-null      object
#  1   age           8 non-null      float64
#  2   company name  8 non-null      object
#  3   salary        8 non-null      float64
#  4   type          8 non-null      object
#  5   Field         8 non-null      object
# dtypes: float64(2), object(4)
# memory usage: 448.0+ bytes

# %%
data.tail()
# Out:
#                   Name   age         company name   salary       type  \
# 6         Babita sahoo  25.0                Wipro  30000.0  Full time
# 7   Nihar ranjan sahoo  31.0  Surya international   5000.0     Intern
# 8    abhishek satpathy   NaN                  abc      NaN     Intern
# 9        Diptesh Bhata  26.0                  NaN  56000.0  Full time
# 10   Satyanarayan rath   NaN                  NaN      NaN        NaN
#
#              Field
# 6   Cyber security
# 7            AI/ML
# 8              NaN
# 9              NaN
# 10             NaN

# %%
new_df.dropna(inplace = True)
# Out:
# C:\Users\Mind-Graph\AppData\Local\Temp\ipykernel_13060\117842389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.dropna(inplace = True)
