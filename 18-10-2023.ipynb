# %%
import numpy as np

arr = np.array([3, 2, 0, 1])

print(np.sort(arr))
# Out:
# [0 1 2 3]

# %%
import numpy as np

arr = np.array(['banana', 'cherry', 'apple'])

print(np.sort(arr))
# Out:
# ['apple' 'banana' 'cherry']

# %%
import numpy as np

arr = np.array([True, False, True])

print(np.sort(arr))
# Out:
# [False  True  True]

# %%
import numpy as np

arr = np.array([[3, 2, 4], [5, 0, 1]])

print(np.sort(arr))
# Out:
# [[2 3 4]
#  [0 1 5]]

# %%
import numpy as np

arr = np.array([41, 42, 43, 44])

x = [True, False, True, False]

newarr = arr[x]

print(newarr)
# Out:
# [41 43]

# %%
import numpy as np

arr = np.array([41, 42, 43, 44])

# Create an empty list
filter_arr = []

# go through each element in arr
for element in arr:
    if element > 42:
        filter_arr.append(True)
        
    else:
        filter_arr.append(False)
        

newarr = arr[filter_arr]

print(filter_arr)
print(newarr)
# Out:
# [False, False, True, True]
# [43 44]

# %% [markdown]
# ## Random number

# %%
from numpy import random

x = random.randint(100)

print(x)
# Out:
# 83

# %%
from numpy import random

x = random.rand()

print(x)
# Out:
# 0.7332238854189901

# %%
from numpy import random

x = random.randint(100, size=(3, 5))

print(x)
# Out:
# [[92 23 22 90 86]
#  [41 42 22 15 40]
#  [83  1 96  7 27]]

# %%
from numpy import random

x = random.rand(3, 5)

print(x)
# Out:
# [[0.52163556 0.22153935 0.39366311 0.58891029 0.62132157]
#  [0.40162253 0.61847128 0.47077067 0.44780285 0.01158155]
#  [0.69316075 0.6787895  0.23183026 0.57600448 0.39812925]]

# %%
from numpy import random

x = random.choice([3, 5, 7, 9])

print(x)
# Out:
# 3

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))

print(x)
# Out:
# [7 5 7 5 7 7 3 7 5 5 7 5 7 7 7 5 7 7 3 7 3 5 7 7 7 7 5 3 7 7 7 5 7 7 7 7 5
#  7 7 3 5 7 3 5 7 7 5 7 7 5 7 7 7 7 7 5 5 7 7 7 7 7 7 5 5 7 5 5 7 7 7 5 5 7
#  5 7 7 7 7 5 5 5 7 7 5 3 3 3 7 7 7 7 7 7 5 7 7 5 7 7]

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[7 7 7 5 3]
#  [7 3 5 5 7]
#  [5 7 5 7 5]]

# %%
from numpy import random
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

random.shuffle(arr)

print(arr)
# Out:
# [4 1 3 2 5]

# %%
from numpy import random
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(random.permutation(arr))
# Out:
# [1 3 2 5 4]

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\mind-graph\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\mind-graph\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: scipy>=1.0 in c:\users\mind-graph\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\mind-graph\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\mind-graph\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mind-graph\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mind-graph\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mind-graph\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mind-graph\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mind-graph\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mind-graph\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mind-graph\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mind-graph\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\mind-graph\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
 pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\mind-graph\anaconda3\lib\site-packages (23.2)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/50/c2/e06851e8cc28dcad7c155f4753da8833ac06a5c704c109313b8d5a62968a/pip-23.2.1-py3-none-any.whl.metadata
#   Downloading pip-23.2.1-py3-none-any.whl.metadata (4.2 kB)
# Downloading pip-23.2.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 2.1/2.1 MB 139.4 kB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2
#     Uninstalling pip-23.2:
#       Successfully uninstalled pip-23.2
# Successfully installed pip-23.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# C:\Users\Mind-Graph\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000), hist=False)

plt.show()
# Out:
# C:\Users\Mind-Graph\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from numpy import random

x = random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [4 4 5 8 3 3 4 5 3 6]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

plt.show()
# Out:
# C:\Users\Mind-Graph\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Mind-Graph\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
