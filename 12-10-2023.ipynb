# %%
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\Mind-Graph\\Downloads\\nba.csv')

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data['Team'].isna().sum()
# Out:
# 1

# %%
data['Name'].isna().sum()
# Out:
# 1

# %%
data['Salary'].isna().sum()
# Out:
# 12

# %%
data.fillna(10,inplace=True)

# %%
data.isna().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
data[['Name','Team']].head(10)
# Out:
#             Name            Team
# 0  Avery Bradley  Boston Celtics
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics
# 4  Jonas Jerebko  Boston Celtics
# 5   Amir Johnson  Boston Celtics
# 6  Jordan Mickey  Boston Celtics
# 7   Kelly Olynyk  Boston Celtics
# 8   Terry Rozier  Boston Celtics
# 9   Marcus Smart  Boston Celtics

# %%
data.rename(columns={'Salary':'salary'},inplace=True)

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457             10              10    10.0       10  10.0     10    10.0
#
#                College     salary
# 0                Texas  7730337.0
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'salary'],
#       dtype='object')

# %%
for i in data:
    print(i)
    if i=='Team':
        print(i)
        for j in 'Team':
            print(j)
#             if j=='Boston Celtics':
#                 print(j.isna().sum())
# Out:
# Name
# Team
# Team
# T
# e
# a
# m
# Number
# Position
# Age
# Height
# Weight
# College
# salary

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

for index, row in df.iterrows():
    print(index, row['A'], row['B'])
# Out:
# 0 1 4
# 1 2 5
# 2 3 6

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df.apply(lambda row: print(row['A'], row['B']), axis=1)
# Out:
# 1 4
# 2 5
# 3 6
# 0    None
# 1    None
# 2    None
# dtype: object

# %%
data.drop(columns={'Team'},inplace=True)

# %%
data
# Out:
#               Name  Number Position   Age Height  Weight            College  \
# 0    Avery Bradley     0.0       PG  25.0    6-2   180.0              Texas
# 1      Jae Crowder    99.0       SF  25.0    6-6   235.0          Marquette
# 2     John Holland    30.0       SG  27.0    6-5   205.0  Boston University
# 3      R.J. Hunter    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Jonas Jerebko     8.0       PF  29.0   6-10   231.0                 10
# ..             ...     ...      ...   ...    ...     ...                ...
# 453   Shelvin Mack     8.0       PG  26.0    6-3   203.0             Butler
# 454      Raul Neto    25.0       PG  24.0    6-1   179.0                 10
# 455   Tibor Pleiss    21.0        C  26.0    7-3   256.0                 10
# 456    Jeff Withey    24.0        C  26.0    7-0   231.0             Kansas
# 457             10    10.0       10  10.0     10    10.0                 10
#
#         salary
# 0    7730337.0
# 1    6796117.0
# ...

# %%
data['Name'].loc[1:5]
# Out:
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# Name: Name, dtype: object

# %%
data['Name'].head(6)
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# Name: Name, dtype: object

# %%
data['Name'].describe([0])
# Out:
# count               458
# unique              458
# top       Avery Bradley
# freq                  1
# Name: Name, dtype: object

# %%
data
# Out:
#               Name  Number Position   Age Height  Weight            College  \
# 0    Avery Bradley     0.0       PG  25.0    6-2   180.0              Texas
# 1      Jae Crowder    99.0       SF  25.0    6-6   235.0          Marquette
# 2     John Holland    30.0       SG  27.0    6-5   205.0  Boston University
# 3      R.J. Hunter    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Jonas Jerebko     8.0       PF  29.0   6-10   231.0                 10
# ..             ...     ...      ...   ...    ...     ...                ...
# 453   Shelvin Mack     8.0       PG  26.0    6-3   203.0             Butler
# 454      Raul Neto    25.0       PG  24.0    6-1   179.0                 10
# 455   Tibor Pleiss    21.0        C  26.0    7-3   256.0                 10
# 456    Jeff Withey    24.0        C  26.0    7-0   231.0             Kansas
# 457             10    10.0       10  10.0     10    10.0                 10
#
#         salary
# 0    7730337.0
# 1    6796117.0
# ...

# %%
data1=pd.read_csv('C:\\Users\\Mind-Graph\\Downloads\\nba.csv')

# %%
data1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data3=data1['Team']

# %%
data4=pd.DataFrame(data3)

# %%
data4
# Out:
#                Team
# 0    Boston Celtics
# 1    Boston Celtics
# 2    Boston Celtics
# 3    Boston Celtics
# 4    Boston Celtics
# ..              ...
# 453       Utah Jazz
# 454       Utah Jazz
# 455       Utah Jazz
# 456       Utah Jazz
# 457             NaN
#
# [458 rows x 1 columns]

# %%
combined_df = pd.concat([data, data4], axis=0)

# %%
combined_df
# Out:
#               Name  Number Position   Age Height  Weight            College  \
# 0    Avery Bradley     0.0       PG  25.0    6-2   180.0              Texas
# 1      Jae Crowder    99.0       SF  25.0    6-6   235.0          Marquette
# 2     John Holland    30.0       SG  27.0    6-5   205.0  Boston University
# 3      R.J. Hunter    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Jonas Jerebko     8.0       PF  29.0   6-10   231.0                 10
# ..             ...     ...      ...   ...    ...     ...                ...
# 453            NaN     NaN      NaN   NaN    NaN     NaN                NaN
# 454            NaN     NaN      NaN   NaN    NaN     NaN                NaN
# 455            NaN     NaN      NaN   NaN    NaN     NaN                NaN
# 456            NaN     NaN      NaN   NaN    NaN     NaN                NaN
# 457            NaN     NaN      NaN   NaN    NaN     NaN                NaN
#
#         salary       Team
# 0    7730337.0        NaN
# ...

# %%
combined_df['Team'].isna().sum()
# Out:
# 459

# %%
combined_df.tail()
# Out:
#     Name  Number Position  Age Height  Weight College  salary       Team
# 453  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN  Utah Jazz
# 454  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN  Utah Jazz
# 455  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN  Utah Jazz
# 456  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN  Utah Jazz
# 457  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN        NaN

# %%
data1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data1.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN
